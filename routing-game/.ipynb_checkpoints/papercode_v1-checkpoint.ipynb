# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import copy

from qiskit import QuantumCircuit, Aer, execute
from qiskit.quantum_info import Operator
from qiskit.extensions import RXGate, RYGate, RZGate

# %%
def generar_mapa():
    a = 0
    while (np.linalg.matrix_rank(a)!=n1):
        a = np.random.randint(n3, size=(n1,n1))
        np.fill_diagonal(a,0)
        a = np.tril(a) + np.tril(a, -1).T
    return a

def generar_red(a):
    net1 = nx.from_numpy_matrix(copy.deepcopy(a))
    for e in net1.edges():
        net1[e[0]][e[1]]['color'] = 'black'
    edge_weights_list = [net1[e[0]][e[1]]['weight'] for e in net1.edges()]
    return net1, edge_weights_list

def generar_paquetes(n1,n2):
    moves = np.zeros([n2, 2])    
    rng = np.random.default_rng()
    for i in range(n2):
        moves[i,:] = rng.choice(n1, size=2, replace=False)    
    colores = []
    for i in range(n2):
        color = np.base_repr(np.random.choice(16777215), base=16)
        colores.append('#{:0>6}'.format(color))    
    return moves, colores

def caminos(net1, moves):
    caminitos = []
    i = 0
    for j in range(len(moves)):
        cam = []
        try:
            p = nx.dijkstra_path(net1,int(moves[j,0]),int(moves[j,1]))
            #print("{:0>3} - Para llegar desde {} hasta {} hay que hacer el siguiente camino: {}".format(j, moves[j,0],moves[j,1], p))        
            for e in range(len(p)-1):
                cam.append(tuple(sorted((p[e], p[e+1]))))    
        except:
            i += 1
            #print("{:0>3} - NO SE PUEDE CONECTAR EL PUNTO {} CON EL PUNTO {}.".format(j+1, int(moves[j,0]),int(moves[j,1])))  
            if i == len(moves):
                return caminitos, True        
        caminitos.append(cam)
    return caminitos, False

def paquetes_en_ruta(caminos, ruta):
    lista = []
    for i in range(n2):
        if ruta in caminos[i]:
            lista.append(i)
    return lista

def opciones_clas(n):
    if n == 1:
        a = {'1': 1}
        x = [a]
    elif n == 2:
        a0 = {'00': 1}
        a1 = {'01': 1}
        a2 = {'10': 1}
        a3 = {'11': 1}
        x = [a0, a1, a2, a3]
    return np.random.choice(x) 
    

def crear_circuito(n):
    I_f = I = np.array([[1, 0],
                  [0, 1]])
    X_f = X = np.array([[0, 1],
                  [1, 0]])    
    for q in range(n-1):
        I_f = np.kron(I_f, I)
        X_f = np.kron(X_f, X)
    J = Operator(1 / np.sqrt(2) * (I_f + 1j * X_f))    
    J_dg = J.adjoint()
    
    if n==1:
        dx = np.pi
        dy = 0
        dz = 0
    elif n==2:    
        dx = np.pi/2
        dy = np.pi/4
        dz = 0

    circ = QuantumCircuit(n,n)
    circ.append(J, range(n))
    for q in range(n):
        circ.append(RXGate(dx),[q])
        circ.append(RYGate(dy),[q])
        circ.append(RZGate(dz),[q])            
    circ.append(J_dg, range(n))
    circ.measure(range(n), range(n))  
    return circ

def juego(lista, tipo):
    m = len(lista)
    if m > 0:
        for r in range(int(np.ceil(np.log2(m)))):
            ganadores = []            
            for j in range(int(np.ceil(m/2))):
                jug = 2 - int(m == j+int(np.ceil(m/2)))
                if tipo == 'c':
                    measurement = opciones_clas(jug)
                        
                elif tipo == 'q':
                    circ = crear_circuito(jug)
                    backend = Aer.get_backend('qasm_simulator')
                    job = execute(circ, backend=backend, shots=1)
                    result = job.result()
                    measurement = result.get_counts(circ)
                
                for k,i in enumerate(list(measurement.keys())[0]):
                    if i=='1':
                        ganadores.append(lista[2*j + k])                    
            lista = ganadores   
            m = len(lista)         
    return lista

# %%
n1 = 10                                                           # cantidad de ciudades
n2_array = np.arange(int(0.5 * n1), int(10 * n1), int(0.5 * n1))  # cantidad de paquetes
n3 = 2                                                            # distancia máxima

costes_totales = []
for tipo in ['c', 'q']:
    if tipo == 'c':
        version = "clásica"
        tests = 200
        print("RESULTADOS DEL JUEGO CLÁSICO:")
    elif tipo == 'q':
        version = "cuántica"
        tests = 100
        print("RESULTADOS DEL JUEGO CUÁNTICO:")
    costes = []
    for cant,n2 in enumerate(n2_array):    
        coste = 0
        for p in range(tests):
            a = generar_mapa()                            # genero matriz
            net1, edge_weights_list = generar_red(a)      # genero red
            net2, edge_weights_list = generar_red(a)      # genero copia de red
            moves, colores = generar_paquetes(n1,n2)      # genero paquetes
            caminitos, flag = caminos(net1, moves)
            all_edges2 = [e for e in net2.edges]
            veces = np.zeros(len(all_edges2))
            i = rutas = tiemp = envio = 0

            while not flag:
                all_edges = [e for e in net1.edges]
                paquetes_ruta = paquetes_en_ruta(caminitos, all_edges[i])
                #print("Todas las rutas", all_edges)
                #print("Rutas de cada paquete:", caminitos)
                #print("Ruta disputada:",all_edges[i])
                #print("Paquetes que disputan:", paquetes_ruta)
                if paquetes_ruta == []:
                    i += 1
                else:
                    i = 0
                    ganadores = juego(paquetes_ruta, tipo)
                    #print("Ganadores:",ganadores, "\n")
                    for x in range(len(ganadores)):
                        envio += 1
                        moves[ganadores[x]] = [-1,-2]
                        for y in caminitos[ganadores[x]]:
                            rutas += 1
                            veces[np.where((np.array(all_edges2) == y).all(axis=1))[0][0]] += 1
                            tiemp += 2 * net2[y[0]][y[1]]['weight'] * veces[np.where((np.array(all_edges2) == y).all(axis=1))[0][0]] - 1
                            net1.remove_edges_from([y])
                            #net2[y[0]][y[1]]['color'] = colores[envio] #ver después
                    caminitos, flag = caminos(net1, moves)

            if (tipo == 'c' and (p+1)%50 == 0) or (tipo == 'q' and (p+1)%25 == 0):
                #print("Uso de rutas:", veces)
                #print("Total de rutas: {}/{}".format(rutas,len(all_edges2)))
                #print("Envíos: {}/{}".format(envio, n2))
                #print("Tiempo:",tiemp)
                print("{:0>3} - Coste final = Tiempo/Envio = {}/{} = {}".format(p+1, tiemp, envio, tiemp/envio))
            coste += tiemp/envio
            #edge_color_list = [net2[e[0]][e[1]]['color'] for e in net2.edges()]
            #edge_weights_list = [net2[e[0]][e[1]]['weight'] for e in net2.edges()]
            #nx.draw_circular(net2,node_color='red',edge_color = edge_color_list, with_labels = True, width=edge_weights_list)
            #plt.show()    
        coste = coste / tests
        costes.append(coste)
        print("{:0>3} - Coste total de la versión {} para {} ciudades y {} paquetes es {}.\n".format(cant+1, version, n1, n2, coste))
    costes_totales.append(costes)
    
plt.figure(figsize=(10,6))
plt.plot(n2_array,costes_totales[0],'blue', label = 'clásico')
plt.plot(n2_array,costes_totales[1],'red', label = 'cuántico')
plt.legend()
plt.title("Coste de los protocolo clásico y cuántico \nen función de la cantidad de paquetes")
plt.show()
# Out:
# RESULTADOS DEL JUEGO CLÁSICO:
# 050 - Coste final = Tiempo/Envio = 7.0/5 = 1.4
# 100 - Coste final = Tiempo/Envio = 8.0/5 = 1.6
# 150 - Coste final = Tiempo/Envio = 8.0/5 = 1.6
# 200 - Coste final = Tiempo/Envio = 9.0/5 = 1.8
# 001 - Coste total de la versión clásica para 10 ciudades y 5 paquetes es 1.7930000000000006.
#
# 050 - Coste final = Tiempo/Envio = 16.0/10 = 1.6
# 100 - Coste final = Tiempo/Envio = 20.0/9 = 2.2222222222222223
# 150 - Coste final = Tiempo/Envio = 29.0/10 = 2.9
# 200 - Coste final = Tiempo/Envio = 17.0/9 = 1.8888888888888888
# 002 - Coste total de la versión clásica para 10 ciudades y 10 paquetes es 2.156648809523809.
#
# 050 - Coste final = Tiempo/Envio = 22.0/11 = 2.0
# 100 - Coste final = Tiempo/Envio = 28.0/15 = 1.8666666666666667
# 150 - Coste final = Tiempo/Envio = 25.0/12 = 2.0833333333333335
# 200 - Coste final = Tiempo/Envio = 20.0/13 = 1.5384615384615385
# 003 - Coste total de la versión clásica para 10 ciudades y 15 paquetes es 2.324340992340992.
#
# 050 - Coste final = Tiempo/Envio = 25.0/12 = 2.0833333333333335
# 100 - Coste final = Tiempo/Envio = 32.0/13 = 2.4615384615384617
# 150 - Coste final = Tiempo/Envio = 24.0/11 = 2.1818181818181817
# 200 - Coste final = Tiempo/Envio = 50.0/12 = 4.166666666666667
# 004 - Coste total de la versión clásica para 10 ciudades y 20 paquetes es 2.565875512043856.
#
# 050 - Coste final = Tiempo/Envio = 45.0/12 = 3.75
# 100 - Coste final = Tiempo/Envio = 33.0/13 = 2.5384615384615383
# 150 - Coste final = Tiempo/Envio = 31.0/17 = 1.8235294117647058
# 200 - Coste final = Tiempo/Envio = 38.0/18 = 2.111111111111111
# 005 - Coste total de la versión clásica para 10 ciudades y 25 paquetes es 2.66898733524817.
#
# 050 - Coste final = Tiempo/Envio = 39.0/16 = 2.4375
# 100 - Coste final = Tiempo/Envio = 29.0/11 = 2.6363636363636362
# 150 - Coste final = Tiempo/Envio = 13.0/5 = 2.6
# 200 - Coste final = Tiempo/Envio = 23.0/9 = 2.5555555555555554
# 006 - Coste total de la versión clásica para 10 ciudades y 30 paquetes es 2.762002086535755.
#
# 050 - Coste final = Tiempo/Envio = 28.0/12 = 2.3333333333333335
# 100 - Coste final = Tiempo/Envio = 38.0/16 = 2.375
# 150 - Coste final = Tiempo/Envio = 27.0/12 = 2.25
# 200 - Coste final = Tiempo/Envio = 26.0/10 = 2.6
# 007 - Coste total de la versión clásica para 10 ciudades y 35 paquetes es 2.740000237894201.
#
# 050 - Coste final = Tiempo/Envio = 56.0/16 = 3.5
# 100 - Coste final = Tiempo/Envio = 25.0/14 = 1.7857142857142858
# 150 - Coste final = Tiempo/Envio = 36.0/12 = 3.0
# 200 - Coste final = Tiempo/Envio = 36.0/13 = 2.769230769230769
# 008 - Coste total de la versión clásica para 10 ciudades y 40 paquetes es 2.801524419969323.
#
# 050 - Coste final = Tiempo/Envio = 43.0/16 = 2.6875
# 100 - Coste final = Tiempo/Envio = 24.0/9 = 2.6666666666666665
# 150 - Coste final = Tiempo/Envio = 19.0/8 = 2.375
# 200 - Coste final = Tiempo/Envio = 24.0/9 = 2.6666666666666665
# 009 - Coste total de la versión clásica para 10 ciudades y 45 paquetes es 2.937558046249416.
#
# 050 - Coste final = Tiempo/Envio = 44.0/16 = 2.75
# 100 - Coste final = Tiempo/Envio = 52.0/14 = 3.7142857142857144
# 150 - Coste final = Tiempo/Envio = 16.0/7 = 2.2857142857142856
# 200 - Coste final = Tiempo/Envio = 38.0/15 = 2.533333333333333
# 010 - Coste total de la versión clásica para 10 ciudades y 50 paquetes es 2.8458841431298687.
#
# 050 - Coste final = Tiempo/Envio = 35.0/13 = 2.6923076923076925
# 100 - Coste final = Tiempo/Envio = 45.0/15 = 3.0
# 150 - Coste final = Tiempo/Envio = 62.0/23 = 2.6956521739130435
# 200 - Coste final = Tiempo/Envio = 53.0/19 = 2.789473684210526
# 011 - Coste total de la versión clásica para 10 ciudades y 55 paquetes es 2.935284829641053.
#
# 050 - Coste final = Tiempo/Envio = 70.0/19 = 3.6842105263157894
# 100 - Coste final = Tiempo/Envio = 43.0/12 = 3.5833333333333335
# 150 - Coste final = Tiempo/Envio = 35.0/13 = 2.6923076923076925
# 200 - Coste final = Tiempo/Envio = 56.0/18 = 3.111111111111111
# 012 - Coste total de la versión clásica para 10 ciudades y 60 paquetes es 2.993994144995908.
#
# 050 - Coste final = Tiempo/Envio = 38.0/11 = 3.4545454545454546
# 100 - Coste final = Tiempo/Envio = 38.0/12 = 3.1666666666666665
# 150 - Coste final = Tiempo/Envio = 48.0/15 = 3.2
# 200 - Coste final = Tiempo/Envio = 41.0/13 = 3.1538461538461537
# 013 - Coste total de la versión clásica para 10 ciudades y 65 paquetes es 3.029586904044528.
#
# 050 - Coste final = Tiempo/Envio = 56.0/13 = 4.3076923076923075
# 100 - Coste final = Tiempo/Envio = 24.0/7 = 3.4285714285714284
# 150 - Coste final = Tiempo/Envio = 40.0/12 = 3.3333333333333335
# 200 - Coste final = Tiempo/Envio = 62.0/18 = 3.4444444444444446
# 014 - Coste total de la versión clásica para 10 ciudades y 70 paquetes es 2.9575063508463626.
#
# 050 - Coste final = Tiempo/Envio = 51.0/16 = 3.1875
# 100 - Coste final = Tiempo/Envio = 52.0/21 = 2.4761904761904763
# 150 - Coste final = Tiempo/Envio = 39.0/14 = 2.7857142857142856
# 200 - Coste final = Tiempo/Envio = 49.0/16 = 3.0625
# 015 - Coste total de la versión clásica para 10 ciudades y 75 paquetes es 2.9737075058220137.
#
# 050 - Coste final = Tiempo/Envio = 59.0/19 = 3.1052631578947367
# 100 - Coste final = Tiempo/Envio = 41.0/15 = 2.7333333333333334
# 150 - Coste final = Tiempo/Envio = 32.0/12 = 2.6666666666666665
# 200 - Coste final = Tiempo/Envio = 48.0/15 = 3.2
# 016 - Coste total de la versión clásica para 10 ciudades y 80 paquetes es 2.986720053593414.
#
# 050 - Coste final = Tiempo/Envio = 36.0/9 = 4.0
# 100 - Coste final = Tiempo/Envio = 42.0/13 = 3.230769230769231
# 150 - Coste final = Tiempo/Envio = 60.0/15 = 4.0
# 200 - Coste final = Tiempo/Envio = 35.0/11 = 3.1818181818181817
# 017 - Coste total de la versión clásica para 10 ciudades y 85 paquetes es 3.08363926790089.
#
# 050 - Coste final = Tiempo/Envio = 39.0/14 = 2.7857142857142856
# 100 - Coste final = Tiempo/Envio = 28.0/10 = 2.8
# 150 - Coste final = Tiempo/Envio = 18.0/8 = 2.25
# 200 - Coste final = Tiempo/Envio = 18.0/10 = 1.8
# 018 - Coste total de la versión clásica para 10 ciudades y 90 paquetes es 2.927327777437112.
#
# 050 - Coste final = Tiempo/Envio = 33.0/14 = 2.357142857142857
# 100 - Coste final = Tiempo/Envio = 31.0/11 = 2.8181818181818183
# 150 - Coste final = Tiempo/Envio = 35.0/14 = 2.5
# 200 - Coste final = Tiempo/Envio = 47.0/20 = 2.35
# 019 - Coste total de la versión clásica para 10 ciudades y 95 paquetes es 3.092649534922943.
#
# RESULTADOS DEL JUEGO CUÁNTICO:
# 025 - Coste final = Tiempo/Envio = 6.0/5 = 1.2
# 050 - Coste final = Tiempo/Envio = 8.0/5 = 1.6
# 075 - Coste final = Tiempo/Envio = 7.0/5 = 1.4
# 100 - Coste final = Tiempo/Envio = 9.0/5 = 1.8
# 001 - Coste total de la versión cuántica para 10 ciudades y 5 paquetes es 1.7181666666666664.
#
# 025 - Coste final = Tiempo/Envio = 16.0/9 = 1.7777777777777777
# 050 - Coste final = Tiempo/Envio = 13.0/4 = 3.25
# 075 - Coste final = Tiempo/Envio = 19.0/9 = 2.111111111111111
# 100 - Coste final = Tiempo/Envio = 17.0/6 = 2.8333333333333335
# 002 - Coste total de la versión cuántica para 10 ciudades y 10 paquetes es 1.950615079365079.
#
# 025 - Coste final = Tiempo/Envio = 18.0/10 = 1.8
# 050 - Coste final = Tiempo/Envio = 17.0/8 = 2.125
# 075 - Coste final = Tiempo/Envio = 20.0/11 = 1.8181818181818181
# 100 - Coste final = Tiempo/Envio = 15.0/8 = 1.875
# 003 - Coste total de la versión cuántica para 10 ciudades y 15 paquetes es 1.9491479076479072.
#
# 025 - Coste final = Tiempo/Envio = 19.0/7 = 2.7142857142857144
# 050 - Coste final = Tiempo/Envio = 21.0/12 = 1.75
# 075 - Coste final = Tiempo/Envio = 18.0/8 = 2.25
# 100 - Coste final = Tiempo/Envio = 17.0/6 = 2.8333333333333335
# 004 - Coste total de la versión cuántica para 10 ciudades y 20 paquetes es 2.0606692474192467.
#
# 025 - Coste final = Tiempo/Envio = 25.0/14 = 1.7857142857142858
# 050 - Coste final = Tiempo/Envio = 33.0/18 = 1.8333333333333333
# 075 - Coste final = Tiempo/Envio = 22.0/11 = 2.0
# 100 - Coste final = Tiempo/Envio = 18.0/7 = 2.5714285714285716
# 005 - Coste total de la versión cuántica para 10 ciudades y 25 paquetes es 1.9982399014384313.
#
# 025 - Coste final = Tiempo/Envio = 23.0/13 = 1.7692307692307692
# 050 - Coste final = Tiempo/Envio = 24.0/13 = 1.8461538461538463
# 075 - Coste final = Tiempo/Envio = 26.0/14 = 1.8571428571428572
# 100 - Coste final = Tiempo/Envio = 18.0/9 = 2.0
# 006 - Coste total de la versión cuántica para 10 ciudades y 30 paquetes es 1.9751588689088693.
#
# 025 - Coste final = Tiempo/Envio = 20.0/10 = 2.0
# 050 - Coste final = Tiempo/Envio = 23.0/10 = 2.3
# 075 - Coste final = Tiempo/Envio = 25.0/13 = 1.9230769230769231
# 100 - Coste final = Tiempo/Envio = 22.0/10 = 2.2
# 007 - Coste total de la versión cuántica para 10 ciudades y 35 paquetes es 1.977558080808081.
#
# 025 - Coste final = Tiempo/Envio = 23.0/12 = 1.9166666666666667
# 050 - Coste final = Tiempo/Envio = 28.0/16 = 1.75
# 075 - Coste final = Tiempo/Envio = 17.0/7 = 2.4285714285714284
# 100 - Coste final = Tiempo/Envio = 26.0/14 = 1.8571428571428572
# 008 - Coste total de la versión cuántica para 10 ciudades y 40 paquetes es 1.997968204997617.
#
# 025 - Coste final = Tiempo/Envio = 19.0/11 = 1.7272727272727273
# 050 - Coste final = Tiempo/Envio = 23.0/14 = 1.6428571428571428
# 075 - Coste final = Tiempo/Envio = 21.0/8 = 2.625
# 100 - Coste final = Tiempo/Envio = 18.0/6 = 3.0
# 009 - Coste total de la versión cuántica para 10 ciudades y 45 paquetes es 2.0511715535926074.
#
# 025 - Coste final = Tiempo/Envio = 27.0/14 = 1.9285714285714286
# 050 - Coste final = Tiempo/Envio = 19.0/10 = 1.9
# 075 - Coste final = Tiempo/Envio = 24.0/12 = 2.0
# 100 - Coste final = Tiempo/Envio = 25.0/12 = 2.0833333333333335
# 010 - Coste total de la versión cuántica para 10 ciudades y 50 paquetes es 1.9796036324786328.
#
# 025 - Coste final = Tiempo/Envio = 22.0/13 = 1.6923076923076923
# 050 - Coste final = Tiempo/Envio = 22.0/10 = 2.2
# 075 - Coste final = Tiempo/Envio = 20.0/14 = 1.4285714285714286
# 100 - Coste final = Tiempo/Envio = 15.0/7 = 2.142857142857143
# 011 - Coste total de la versión cuántica para 10 ciudades y 55 paquetes es 1.9923222844407054.
#
# 025 - Coste final = Tiempo/Envio = 29.0/17 = 1.7058823529411764
# 050 - Coste final = Tiempo/Envio = 20.0/9 = 2.2222222222222223
# 075 - Coste final = Tiempo/Envio = 21.0/12 = 1.75
# 100 - Coste final = Tiempo/Envio = 25.0/15 = 1.6666666666666667
# 012 - Coste total de la versión cuántica para 10 ciudades y 60 paquetes es 1.999188194889046.
#
# 025 - Coste final = Tiempo/Envio = 25.0/12 = 2.0833333333333335
# 050 - Coste final = Tiempo/Envio = 26.0/12 = 2.1666666666666665
# 075 - Coste final = Tiempo/Envio = 19.0/9 = 2.111111111111111
# 100 - Coste final = Tiempo/Envio = 22.0/11 = 2.0
# 013 - Coste total de la versión cuántica para 10 ciudades y 65 paquetes es 1.9911575777164017.
#
# 025 - Coste final = Tiempo/Envio = 27.0/16 = 1.6875
# 050 - Coste final = Tiempo/Envio = 21.0/13 = 1.6153846153846154
# 075 - Coste final = Tiempo/Envio = 30.0/16 = 1.875
# 100 - Coste final = Tiempo/Envio = 20.0/10 = 2.0
# 014 - Coste total de la versión cuántica para 10 ciudades y 70 paquetes es 2.0035640903214427.
#
# 025 - Coste final = Tiempo/Envio = 21.0/9 = 2.3333333333333335
# 050 - Coste final = Tiempo/Envio = 23.0/12 = 1.9166666666666667
# 075 - Coste final = Tiempo/Envio = 26.0/12 = 2.1666666666666665
# 100 - Coste final = Tiempo/Envio = 17.0/9 = 1.8888888888888888
# 015 - Coste total de la versión cuántica para 10 ciudades y 75 paquetes es 1.9968897124117715.
#
# 025 - Coste final = Tiempo/Envio = 22.0/11 = 2.0
# 050 - Coste final = Tiempo/Envio = 28.0/14 = 2.0
# 075 - Coste final = Tiempo/Envio = 26.0/16 = 1.625
# 100 - Coste final = Tiempo/Envio = 22.0/10 = 2.2
# 016 - Coste total de la versión cuántica para 10 ciudades y 80 paquetes es 1.9905517293164348.
#
# 025 - Coste final = Tiempo/Envio = 19.0/10 = 1.9
# 050 - Coste final = Tiempo/Envio = 28.0/16 = 1.75
# 075 - Coste final = Tiempo/Envio = 19.0/10 = 1.9
# 100 - Coste final = Tiempo/Envio = 25.0/14 = 1.7857142857142858
# 017 - Coste total de la versión cuántica para 10 ciudades y 85 paquetes es 1.9873990715167182.
#
# 025 - Coste final = Tiempo/Envio = 26.0/14 = 1.8571428571428572
# 050 - Coste final = Tiempo/Envio = 30.0/16 = 1.875
# 075 - Coste final = Tiempo/Envio = 23.0/11 = 2.090909090909091
# 100 - Coste final = Tiempo/Envio = 22.0/11 = 2.0
# 018 - Coste total de la versión cuántica para 10 ciudades y 90 paquetes es 2.0014060016780606.
#
# 025 - Coste final = Tiempo/Envio = 23.0/10 = 2.3
# 050 - Coste final = Tiempo/Envio = 22.0/10 = 2.2
# 075 - Coste final = Tiempo/Envio = 24.0/14 = 1.7142857142857142
# 100 - Coste final = Tiempo/Envio = 22.0/11 = 2.0
# 019 - Coste total de la versión cuántica para 10 ciudades y 95 paquetes es 2.029537298485827.
