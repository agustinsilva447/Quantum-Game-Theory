# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import copy

from qiskit import QuantumCircuit, Aer, execute
from qiskit.quantum_info import Operator
from qiskit.extensions import RXGate, RYGate, RZGate

# %%
def generar_mapa():
    a = 0
    while (np.linalg.matrix_rank(a)!=n1):
        a = np.random.randint(n3, size=(n1,n1))
        np.fill_diagonal(a,0)
        a = np.tril(a) + np.tril(a, -1).T
    return a

def generar_red(a):
    net1 = nx.from_numpy_matrix(copy.deepcopy(a))
    for e in net1.edges():
        net1[e[0]][e[1]]['color'] = 'black'
    edge_weights_list = [net1[e[0]][e[1]]['weight'] for e in net1.edges()]
    return net1, edge_weights_list

def generar_paquetes(n1,n2):
    moves = np.zeros([n2, 2])    
    rng = np.random.default_rng()
    for i in range(n2):
        moves[i,:] = rng.choice(n1, size=2, replace=False)
    return moves

# %%
n1 = 10    # cantidad de ciudades
n2 = 25    # cantidad de viajes
n3 = 2     # distancia máxima

a = generar_mapa()                            # genero matriz
net1, edge_weights_list = generar_red(a)      # genero red
moves = generar_paquetes(n1,n2)               # genero paquetes

#print("Matriz de rutas: \n{}".format(a))
print("Matriz de movimientos: \n{}".format(moves))
nx.draw_circular(net1, with_labels=True, width=edge_weights_list)
plt.show()
# Out:
# Matriz de movimientos:
# [[4. 5.]
#  [4. 3.]
#  [5. 8.]
#  [2. 3.]
#  [1. 9.]
#  [0. 5.]
#  [7. 5.]
#  [9. 7.]
#  [7. 0.]
#  [0. 6.]
#  [4. 6.]
#  [6. 7.]
#  [3. 5.]
#  [6. 4.]
#  [2. 4.]
#  [7. 5.]
#  [1. 9.]
#  [6. 0.]
#  [4. 3.]
#  [6. 7.]
#  [7. 3.]
#  [4. 2.]
#  [5. 0.]
#  [7. 8.]
#  [8. 1.]]

# %%
def caminos(net1, moves):
    caminitos = []
    i = 0
    for j in range(len(moves)):
        cam = []
        try:
            p = nx.dijkstra_path(net1,int(moves[j,0]),int(moves[j,1]))
            print("{:0>3} - Para llegar desde {} hasta {} hay que hacer el siguiente camino: {}".format(j, moves[j,0],moves[j,1], p))        
            for e in range(len(p)-1):
                cam.append(tuple(sorted((p[e], p[e+1]))))    
        except:
            i += 1
            print("{:0>3} - NO SE PUEDE CONECTAR EL PUNTO {} CON EL PUNTO {}.".format(j+1, int(moves[j,0]),int(moves[j,1])))  
            if i == len(moves):
                return caminitos, True        
        caminitos.append(cam)
    return caminitos, False

def paquetes_en_ruta(caminos, ruta):
    lista = []
    for i in range(n2):
        if ruta in caminos[i]:
            lista.append(i)
    return lista

def opciones_clas(n):
    if n == 1:
        a = {'1': 1}
        x = [a]
    elif n == 2:
        a0 = {'00': 1}
        a1 = {'01': 1}
        a2 = {'10': 1}
        a3 = {'11': 1}
        x = [a0, a1, a2, a3]
    return np.random.choice(x) 
    

def crear_circuito(n):
    I_f = I = np.array([[1, 0],
                  [0, 1]])
    X_f = X = np.array([[0, 1],
                  [1, 0]])    
    for q in range(n-1):
        I_f = np.kron(I_f, I)
        X_f = np.kron(X_f, X)
    J = Operator(1 / np.sqrt(2) * (I_f + 1j * X_f))    
    J_dg = J.adjoint()
    
    if n==1:
        dx = np.pi
        dy = 0
        dz = 0
    elif n==2:    
        dx = np.pi/2
        dy = np.pi/4
        dz = 0

    circ = QuantumCircuit(n,n)
    circ.append(J, range(n))
    for q in range(n):
        circ.append(RXGate(dx),[q])
        circ.append(RYGate(dy),[q])
        circ.append(RZGate(dz),[q])            
    circ.append(J_dg, range(n))
    circ.measure(range(n), range(n))  
    return circ

def juego(lista, tipo):
    m = len(lista)
    if m > 0:
        for r in range(int(np.ceil(np.log2(m)))):
            ganadores = []            
            for j in range(int(np.ceil(m/2))):
                jug = 2 - int(m == j+int(np.ceil(m/2)))
                if tipo == 'c':
                    measurement = opciones_clas(jug)
                        
                elif tipo == 'q':
                    circ = crear_circuito(jug)
                    backend = Aer.get_backend('qasm_simulator')
                    job = execute(circ, backend=backend, shots=1)
                    result = job.result()
                    measurement = result.get_counts(circ)
                
                for k,i in enumerate(list(measurement.keys())[0]):
                    if i=='1':
                        ganadores.append(lista[2*j + k])                    
            lista = ganadores   
            m = len(lista)         
    return lista

# %%
#print("Número total de Rutas: {}".format(len(all_edges)))
#for i in range(len(all_edges)):
#    for j in range(n2):
#        if all_edges[i] in caminitos[j]:
#            print("La ruta {} {} la recorre el viaje {} {}".format(i,all_edges[i],j,caminitos[j]))

# %%
all_edges = [e for e in net1.edges]
caminitos, flag = caminos(net1, moves)
print("Todas las posibles rutas:",all_edges)
print("Todos las rutas de cada viaje:",caminitos)
# Out:
# 000 - Para llegar desde 4.0 hasta 5.0 hay que hacer el siguiente camino: [4, 5]
# 001 - Para llegar desde 4.0 hasta 3.0 hay que hacer el siguiente camino: [4, 0, 3]
# 002 - Para llegar desde 5.0 hasta 8.0 hay que hacer el siguiente camino: [5, 2, 8]
# 003 - Para llegar desde 2.0 hasta 3.0 hay que hacer el siguiente camino: [2, 3]
# 004 - Para llegar desde 1.0 hasta 9.0 hay que hacer el siguiente camino: [1, 9]
# 005 - Para llegar desde 0.0 hasta 5.0 hay que hacer el siguiente camino: [0, 5]
# 006 - Para llegar desde 7.0 hasta 5.0 hay que hacer el siguiente camino: [7, 0, 5]
# 007 - Para llegar desde 9.0 hasta 7.0 hay que hacer el siguiente camino: [9, 1, 7]
# 008 - Para llegar desde 7.0 hasta 0.0 hay que hacer el siguiente camino: [7, 0]
# 009 - Para llegar desde 0.0 hasta 6.0 hay que hacer el siguiente camino: [0, 6]
# 010 - Para llegar desde 4.0 hasta 6.0 hay que hacer el siguiente camino: [4, 0, 6]
# 011 - Para llegar desde 6.0 hasta 7.0 hay que hacer el siguiente camino: [6, 0, 7]
# 012 - Para llegar desde 3.0 hasta 5.0 hay que hacer el siguiente camino: [3, 5]
# 013 - Para llegar desde 6.0 hasta 4.0 hay que hacer el siguiente camino: [6, 0, 4]
# 014 - Para llegar desde 2.0 hasta 4.0 hay que hacer el siguiente camino: [2, 1, 4]
# 015 - Para llegar desde 7.0 hasta 5.0 hay que hacer el siguiente camino: [7, 0, 5]
# 016 - Para llegar desde 1.0 hasta 9.0 hay que hacer el siguiente camino: [1, 9]
# 017 - Para llegar desde 6.0 hasta 0.0 hay que hacer el siguiente camino: [6, 0]
# 018 - Para llegar desde 4.0 hasta 3.0 hay que hacer el siguiente camino: [4, 0, 3]
# 019 - Para llegar desde 6.0 hasta 7.0 hay que hacer el siguiente camino: [6, 0, 7]
# 020 - Para llegar desde 7.0 hasta 3.0 hay que hacer el siguiente camino: [7, 3]
# 021 - Para llegar desde 4.0 hasta 2.0 hay que hacer el siguiente camino: [4, 1, 2]
# 022 - Para llegar desde 5.0 hasta 0.0 hay que hacer el siguiente camino: [5, 0]
# 023 - Para llegar desde 7.0 hasta 8.0 hay que hacer el siguiente camino: [7, 8]
# 024 - Para llegar desde 8.0 hasta 1.0 hay que hacer el siguiente camino: [8, 1]
# Todas las posibles rutas: [(0, 1), (0, 3), (0, 4), (0, 5), (0, 6), (0, 7), (1, 2), (1, 4), (1, 6), (1, 7), (1, 8), (1, 9), (2, 3), (2, 5), (2, 7), (2, 8), (3, 5), (3, 7), (3, 9), (4, 5), (4, 9), (5, 9), (7, 8), (8, 9)]
# Todos las rutas de cada viaje: [[(4, 5)], [(0, 4), (0, 3)], [(2, 5), (2, 8)], [(2, 3)], [(1, 9)], [(0, 5)], [(0, 7), (0, 5)], [(1, 9), (1, 7)], [(0, 7)], [(0, 6)], [(0, 4), (0, 6)], [(0, 6), (0, 7)], [(3, 5)], [(0, 6), (0, 4)], [(1, 2), (1, 4)], [(0, 7), (0, 5)], [(1, 9)], [(0, 6)], [(0, 4), (0, 3)], [(0, 6), (0, 7)], [(3, 7)], [(1, 4), (1, 2)], [(0, 5)], [(7, 8)], [(1, 8)]]

# %%
for n in range(len(all_edges)):
    print("Ruta {}:".format(n))
    paquetes_ruta = paquetes_en_ruta(caminitos, all_edges[n])
    print(paquetes_ruta)
    ganadores = juego(paquetes_ruta, 'q')
    print(ganadores)
    print("")
# Out:
# Ruta 0:
# []
# []
#
# Ruta 1:
# [1, 18]
# [18]
#
# Ruta 2:
# [1, 10, 13, 18]
# [13]
#
# Ruta 3:
# [5, 6, 15, 22]
# [6]
#
# Ruta 4:
# [9, 10, 11, 13, 17, 19]
# [9]
#
# Ruta 5:
# [6, 8, 11, 15, 19]
# [19]
#
# Ruta 6:
# [14, 21]
# [21]
#
# Ruta 7:
# [14, 21]
# [14]
#
# Ruta 8:
# []
# []
#
# Ruta 9:
# [7]
# [7]
#
# Ruta 10:
# [24]
# [24]
#
# Ruta 11:
# [4, 7, 16]
# [7]
#
# Ruta 12:
# [3]
# [3]
#
# Ruta 13:
# [2]
# [2]
#
# Ruta 14:
# []
# []
#
# Ruta 15:
# [2]
# [2]
#
# Ruta 16:
# [12]
# [12]
#
# Ruta 17:
# [20]
# [20]
#
# Ruta 18:
# []
# []
#
# Ruta 19:
# [0]
# [0]
#
# Ruta 20:
# []
# []
#
# Ruta 21:
# []
# []
#
# Ruta 22:
# [23]
# [23]
#
# Ruta 23:
# []
# []

# %%
caminitos, flag = caminos(net1, moves)
i = 0
while not flag:
    all_edges = [e for e in net1.edges]
    paquetes_ruta = paquetes_en_ruta(caminitos, all_edges[i])
    if paquetes_ruta == []:
        i += 1
    else:
        i = 0
        ganadores = juego(paquetes_ruta, 'q')
        for x in range(len(ganadores)):
            for y in caminitos[ganadores[x]]:
                net1.remove_edges_from([y])
        print("Los jugadores número {} ganaron las rutas {}".format(ganadores, caminitos[ganadores[0]]))
        moves[ganadores[0]] = [-1,-2]
        caminitos, flag = caminos(net1, moves)
# Out:
# 000 - Para llegar desde 4.0 hasta 5.0 hay que hacer el siguiente camino: [4, 5]
# 001 - Para llegar desde 4.0 hasta 3.0 hay que hacer el siguiente camino: [4, 0, 3]
# 002 - Para llegar desde 5.0 hasta 8.0 hay que hacer el siguiente camino: [5, 2, 8]
# 003 - Para llegar desde 2.0 hasta 3.0 hay que hacer el siguiente camino: [2, 3]
# 004 - Para llegar desde 1.0 hasta 9.0 hay que hacer el siguiente camino: [1, 9]
# 005 - Para llegar desde 0.0 hasta 5.0 hay que hacer el siguiente camino: [0, 5]
# 006 - Para llegar desde 7.0 hasta 5.0 hay que hacer el siguiente camino: [7, 0, 5]
# 007 - Para llegar desde 9.0 hasta 7.0 hay que hacer el siguiente camino: [9, 1, 7]
# 008 - Para llegar desde 7.0 hasta 0.0 hay que hacer el siguiente camino: [7, 0]
# 009 - Para llegar desde 0.0 hasta 6.0 hay que hacer el siguiente camino: [0, 6]
# 010 - Para llegar desde 4.0 hasta 6.0 hay que hacer el siguiente camino: [4, 0, 6]
# 011 - Para llegar desde 6.0 hasta 7.0 hay que hacer el siguiente camino: [6, 0, 7]
# 012 - Para llegar desde 3.0 hasta 5.0 hay que hacer el siguiente camino: [3, 5]
# 013 - Para llegar desde 6.0 hasta 4.0 hay que hacer el siguiente camino: [6, 0, 4]
# 014 - Para llegar desde 2.0 hasta 4.0 hay que hacer el siguiente camino: [2, 1, 4]
# 015 - Para llegar desde 7.0 hasta 5.0 hay que hacer el siguiente camino: [7, 0, 5]
# 016 - Para llegar desde 1.0 hasta 9.0 hay que hacer el siguiente camino: [1, 9]
# 017 - Para llegar desde 6.0 hasta 0.0 hay que hacer el siguiente camino: [6, 0]
# 018 - Para llegar desde 4.0 hasta 3.0 hay que hacer el siguiente camino: [4, 0, 3]
# 019 - Para llegar desde 6.0 hasta 7.0 hay que hacer el siguiente camino: [6, 0, 7]
# 020 - Para llegar desde 7.0 hasta 3.0 hay que hacer el siguiente camino: [7, 3]
# 021 - Para llegar desde 4.0 hasta 2.0 hay que hacer el siguiente camino: [4, 1, 2]
# 022 - Para llegar desde 5.0 hasta 0.0 hay que hacer el siguiente camino: [5, 0]
# 023 - Para llegar desde 7.0 hasta 8.0 hay que hacer el siguiente camino: [7, 8]
# 024 - Para llegar desde 8.0 hasta 1.0 hay que hacer el siguiente camino: [8, 1]
# Los jugadores número [1] ganaron las rutas [(0, 4), (0, 3)]
# 000 - Para llegar desde 4.0 hasta 5.0 hay que hacer el siguiente camino: [4, 5]
# 002 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 002 - Para llegar desde 5.0 hasta 8.0 hay que hacer el siguiente camino: [5, 2, 8]
# 003 - Para llegar desde 2.0 hasta 3.0 hay que hacer el siguiente camino: [2, 3]
# 004 - Para llegar desde 1.0 hasta 9.0 hay que hacer el siguiente camino: [1, 9]
# 005 - Para llegar desde 0.0 hasta 5.0 hay que hacer el siguiente camino: [0, 5]
# 006 - Para llegar desde 7.0 hasta 5.0 hay que hacer el siguiente camino: [7, 0, 5]
# 007 - Para llegar desde 9.0 hasta 7.0 hay que hacer el siguiente camino: [9, 1, 7]
# 008 - Para llegar desde 7.0 hasta 0.0 hay que hacer el siguiente camino: [7, 0]
# 009 - Para llegar desde 0.0 hasta 6.0 hay que hacer el siguiente camino: [0, 6]
# 010 - Para llegar desde 4.0 hasta 6.0 hay que hacer el siguiente camino: [4, 1, 6]
# 011 - Para llegar desde 6.0 hasta 7.0 hay que hacer el siguiente camino: [6, 0, 7]
# 012 - Para llegar desde 3.0 hasta 5.0 hay que hacer el siguiente camino: [3, 5]
# 013 - Para llegar desde 6.0 hasta 4.0 hay que hacer el siguiente camino: [6, 1, 4]
# 014 - Para llegar desde 2.0 hasta 4.0 hay que hacer el siguiente camino: [2, 1, 4]
# 015 - Para llegar desde 7.0 hasta 5.0 hay que hacer el siguiente camino: [7, 0, 5]
# 016 - Para llegar desde 1.0 hasta 9.0 hay que hacer el siguiente camino: [1, 9]
# 017 - Para llegar desde 6.0 hasta 0.0 hay que hacer el siguiente camino: [6, 0]
# 018 - Para llegar desde 4.0 hasta 3.0 hay que hacer el siguiente camino: [4, 5, 3]
# 019 - Para llegar desde 6.0 hasta 7.0 hay que hacer el siguiente camino: [6, 0, 7]
# 020 - Para llegar desde 7.0 hasta 3.0 hay que hacer el siguiente camino: [7, 3]
# 021 - Para llegar desde 4.0 hasta 2.0 hay que hacer el siguiente camino: [4, 1, 2]
# 022 - Para llegar desde 5.0 hasta 0.0 hay que hacer el siguiente camino: [5, 0]
# 023 - Para llegar desde 7.0 hasta 8.0 hay que hacer el siguiente camino: [7, 8]
# 024 - Para llegar desde 8.0 hasta 1.0 hay que hacer el siguiente camino: [8, 1]
# Los jugadores número [6] ganaron las rutas [(0, 7), (0, 5)]
# 000 - Para llegar desde 4.0 hasta 5.0 hay que hacer el siguiente camino: [4, 5]
# 002 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 002 - Para llegar desde 5.0 hasta 8.0 hay que hacer el siguiente camino: [5, 2, 8]
# 003 - Para llegar desde 2.0 hasta 3.0 hay que hacer el siguiente camino: [2, 3]
# 004 - Para llegar desde 1.0 hasta 9.0 hay que hacer el siguiente camino: [1, 9]
# 005 - Para llegar desde 0.0 hasta 5.0 hay que hacer el siguiente camino: [0, 1, 2, 5]
# 007 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 007 - Para llegar desde 9.0 hasta 7.0 hay que hacer el siguiente camino: [9, 1, 7]
# 008 - Para llegar desde 7.0 hasta 0.0 hay que hacer el siguiente camino: [7, 1, 0]
# 009 - Para llegar desde 0.0 hasta 6.0 hay que hacer el siguiente camino: [0, 6]
# 010 - Para llegar desde 4.0 hasta 6.0 hay que hacer el siguiente camino: [4, 1, 6]
# 011 - Para llegar desde 6.0 hasta 7.0 hay que hacer el siguiente camino: [6, 1, 7]
# 012 - Para llegar desde 3.0 hasta 5.0 hay que hacer el siguiente camino: [3, 5]
# 013 - Para llegar desde 6.0 hasta 4.0 hay que hacer el siguiente camino: [6, 1, 4]
# 014 - Para llegar desde 2.0 hasta 4.0 hay que hacer el siguiente camino: [2, 1, 4]
# 015 - Para llegar desde 7.0 hasta 5.0 hay que hacer el siguiente camino: [7, 2, 5]
# 016 - Para llegar desde 1.0 hasta 9.0 hay que hacer el siguiente camino: [1, 9]
# 017 - Para llegar desde 6.0 hasta 0.0 hay que hacer el siguiente camino: [6, 0]
# 018 - Para llegar desde 4.0 hasta 3.0 hay que hacer el siguiente camino: [4, 5, 3]
# 019 - Para llegar desde 6.0 hasta 7.0 hay que hacer el siguiente camino: [6, 1, 7]
# 020 - Para llegar desde 7.0 hasta 3.0 hay que hacer el siguiente camino: [7, 3]
# 021 - Para llegar desde 4.0 hasta 2.0 hay que hacer el siguiente camino: [4, 1, 2]
# 022 - Para llegar desde 5.0 hasta 0.0 hay que hacer el siguiente camino: [5, 2, 1, 0]
# 023 - Para llegar desde 7.0 hasta 8.0 hay que hacer el siguiente camino: [7, 8]
# 024 - Para llegar desde 8.0 hasta 1.0 hay que hacer el siguiente camino: [8, 1]
# Los jugadores número [5] ganaron las rutas [(0, 1), (1, 2), (2, 5)]
# 000 - Para llegar desde 4.0 hasta 5.0 hay que hacer el siguiente camino: [4, 5]
# 002 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 002 - Para llegar desde 5.0 hasta 8.0 hay que hacer el siguiente camino: [5, 9, 8]
# 003 - Para llegar desde 2.0 hasta 3.0 hay que hacer el siguiente camino: [2, 3]
# 004 - Para llegar desde 1.0 hasta 9.0 hay que hacer el siguiente camino: [1, 9]
# 006 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 007 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 007 - Para llegar desde 9.0 hasta 7.0 hay que hacer el siguiente camino: [9, 1, 7]
# 008 - Para llegar desde 7.0 hasta 0.0 hay que hacer el siguiente camino: [7, 1, 6, 0]
# 009 - Para llegar desde 0.0 hasta 6.0 hay que hacer el siguiente camino: [0, 6]
# 010 - Para llegar desde 4.0 hasta 6.0 hay que hacer el siguiente camino: [4, 1, 6]
# 011 - Para llegar desde 6.0 hasta 7.0 hay que hacer el siguiente camino: [6, 1, 7]
# 012 - Para llegar desde 3.0 hasta 5.0 hay que hacer el siguiente camino: [3, 5]
# 013 - Para llegar desde 6.0 hasta 4.0 hay que hacer el siguiente camino: [6, 1, 4]
# 014 - Para llegar desde 2.0 hasta 4.0 hay que hacer el siguiente camino: [2, 3, 5, 4]
# 015 - Para llegar desde 7.0 hasta 5.0 hay que hacer el siguiente camino: [7, 3, 5]
# 016 - Para llegar desde 1.0 hasta 9.0 hay que hacer el siguiente camino: [1, 9]
# 017 - Para llegar desde 6.0 hasta 0.0 hay que hacer el siguiente camino: [6, 0]
# 018 - Para llegar desde 4.0 hasta 3.0 hay que hacer el siguiente camino: [4, 5, 3]
# 019 - Para llegar desde 6.0 hasta 7.0 hay que hacer el siguiente camino: [6, 1, 7]
# 020 - Para llegar desde 7.0 hasta 3.0 hay que hacer el siguiente camino: [7, 3]
# 021 - Para llegar desde 4.0 hasta 2.0 hay que hacer el siguiente camino: [4, 1, 7, 2]
# 022 - Para llegar desde 5.0 hasta 0.0 hay que hacer el siguiente camino: [5, 4, 1, 6, 0]
# 023 - Para llegar desde 7.0 hasta 8.0 hay que hacer el siguiente camino: [7, 8]
# 024 - Para llegar desde 8.0 hasta 1.0 hay que hacer el siguiente camino: [8, 1]
# Los jugadores número [17] ganaron las rutas [(0, 6)]
# 000 - Para llegar desde 4.0 hasta 5.0 hay que hacer el siguiente camino: [4, 5]
# 002 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 002 - Para llegar desde 5.0 hasta 8.0 hay que hacer el siguiente camino: [5, 9, 8]
# 003 - Para llegar desde 2.0 hasta 3.0 hay que hacer el siguiente camino: [2, 3]
# 004 - Para llegar desde 1.0 hasta 9.0 hay que hacer el siguiente camino: [1, 9]
# 006 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 007 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 007 - Para llegar desde 9.0 hasta 7.0 hay que hacer el siguiente camino: [9, 1, 7]
# 009 - NO SE PUEDE CONECTAR EL PUNTO 7 CON EL PUNTO 0.
# 010 - NO SE PUEDE CONECTAR EL PUNTO 0 CON EL PUNTO 6.
# 010 - Para llegar desde 4.0 hasta 6.0 hay que hacer el siguiente camino: [4, 1, 6]
# 011 - Para llegar desde 6.0 hasta 7.0 hay que hacer el siguiente camino: [6, 1, 7]
# 012 - Para llegar desde 3.0 hasta 5.0 hay que hacer el siguiente camino: [3, 5]
# 013 - Para llegar desde 6.0 hasta 4.0 hay que hacer el siguiente camino: [6, 1, 4]
# 014 - Para llegar desde 2.0 hasta 4.0 hay que hacer el siguiente camino: [2, 3, 5, 4]
# 015 - Para llegar desde 7.0 hasta 5.0 hay que hacer el siguiente camino: [7, 3, 5]
# 016 - Para llegar desde 1.0 hasta 9.0 hay que hacer el siguiente camino: [1, 9]
# 018 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 018 - Para llegar desde 4.0 hasta 3.0 hay que hacer el siguiente camino: [4, 5, 3]
# 019 - Para llegar desde 6.0 hasta 7.0 hay que hacer el siguiente camino: [6, 1, 7]
# 020 - Para llegar desde 7.0 hasta 3.0 hay que hacer el siguiente camino: [7, 3]
# 021 - Para llegar desde 4.0 hasta 2.0 hay que hacer el siguiente camino: [4, 1, 7, 2]
# 023 - NO SE PUEDE CONECTAR EL PUNTO 5 CON EL PUNTO 0.
# 023 - Para llegar desde 7.0 hasta 8.0 hay que hacer el siguiente camino: [7, 8]
# 024 - Para llegar desde 8.0 hasta 1.0 hay que hacer el siguiente camino: [8, 1]
# Los jugadores número [10] ganaron las rutas [(1, 4), (1, 6)]
# 000 - Para llegar desde 4.0 hasta 5.0 hay que hacer el siguiente camino: [4, 5]
# 002 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 002 - Para llegar desde 5.0 hasta 8.0 hay que hacer el siguiente camino: [5, 9, 8]
# 003 - Para llegar desde 2.0 hasta 3.0 hay que hacer el siguiente camino: [2, 3]
# 004 - Para llegar desde 1.0 hasta 9.0 hay que hacer el siguiente camino: [1, 9]
# 006 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 007 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 007 - Para llegar desde 9.0 hasta 7.0 hay que hacer el siguiente camino: [9, 1, 7]
# 009 - NO SE PUEDE CONECTAR EL PUNTO 7 CON EL PUNTO 0.
# 010 - NO SE PUEDE CONECTAR EL PUNTO 0 CON EL PUNTO 6.
# 011 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 012 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 7.
# 012 - Para llegar desde 3.0 hasta 5.0 hay que hacer el siguiente camino: [3, 5]
# 014 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 4.
# 014 - Para llegar desde 2.0 hasta 4.0 hay que hacer el siguiente camino: [2, 3, 5, 4]
# 015 - Para llegar desde 7.0 hasta 5.0 hay que hacer el siguiente camino: [7, 3, 5]
# 016 - Para llegar desde 1.0 hasta 9.0 hay que hacer el siguiente camino: [1, 9]
# 018 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 018 - Para llegar desde 4.0 hasta 3.0 hay que hacer el siguiente camino: [4, 5, 3]
# 020 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 7.
# 020 - Para llegar desde 7.0 hasta 3.0 hay que hacer el siguiente camino: [7, 3]
# 021 - Para llegar desde 4.0 hasta 2.0 hay que hacer el siguiente camino: [4, 5, 3, 2]
# 023 - NO SE PUEDE CONECTAR EL PUNTO 5 CON EL PUNTO 0.
# 023 - Para llegar desde 7.0 hasta 8.0 hay que hacer el siguiente camino: [7, 8]
# 024 - Para llegar desde 8.0 hasta 1.0 hay que hacer el siguiente camino: [8, 1]
# Los jugadores número [7] ganaron las rutas [(1, 9), (1, 7)]
# 000 - Para llegar desde 4.0 hasta 5.0 hay que hacer el siguiente camino: [4, 5]
# 002 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 002 - Para llegar desde 5.0 hasta 8.0 hay que hacer el siguiente camino: [5, 9, 8]
# 003 - Para llegar desde 2.0 hasta 3.0 hay que hacer el siguiente camino: [2, 3]
# 004 - Para llegar desde 1.0 hasta 9.0 hay que hacer el siguiente camino: [1, 8, 9]
# 006 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 007 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 008 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 009 - NO SE PUEDE CONECTAR EL PUNTO 7 CON EL PUNTO 0.
# 010 - NO SE PUEDE CONECTAR EL PUNTO 0 CON EL PUNTO 6.
# 011 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 012 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 7.
# 012 - Para llegar desde 3.0 hasta 5.0 hay que hacer el siguiente camino: [3, 5]
# 014 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 4.
# 014 - Para llegar desde 2.0 hasta 4.0 hay que hacer el siguiente camino: [2, 3, 5, 4]
# 015 - Para llegar desde 7.0 hasta 5.0 hay que hacer el siguiente camino: [7, 3, 5]
# 016 - Para llegar desde 1.0 hasta 9.0 hay que hacer el siguiente camino: [1, 8, 9]
# 018 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 018 - Para llegar desde 4.0 hasta 3.0 hay que hacer el siguiente camino: [4, 5, 3]
# 020 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 7.
# 020 - Para llegar desde 7.0 hasta 3.0 hay que hacer el siguiente camino: [7, 3]
# 021 - Para llegar desde 4.0 hasta 2.0 hay que hacer el siguiente camino: [4, 5, 3, 2]
# 023 - NO SE PUEDE CONECTAR EL PUNTO 5 CON EL PUNTO 0.
# 023 - Para llegar desde 7.0 hasta 8.0 hay que hacer el siguiente camino: [7, 8]
# 024 - Para llegar desde 8.0 hasta 1.0 hay que hacer el siguiente camino: [8, 1]
# Los jugadores número [24] ganaron las rutas [(1, 8)]
# 000 - Para llegar desde 4.0 hasta 5.0 hay que hacer el siguiente camino: [4, 5]
# 002 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 002 - Para llegar desde 5.0 hasta 8.0 hay que hacer el siguiente camino: [5, 9, 8]
# 003 - Para llegar desde 2.0 hasta 3.0 hay que hacer el siguiente camino: [2, 3]
# 005 - NO SE PUEDE CONECTAR EL PUNTO 1 CON EL PUNTO 9.
# 006 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 007 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 008 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 009 - NO SE PUEDE CONECTAR EL PUNTO 7 CON EL PUNTO 0.
# 010 - NO SE PUEDE CONECTAR EL PUNTO 0 CON EL PUNTO 6.
# 011 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 012 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 7.
# 012 - Para llegar desde 3.0 hasta 5.0 hay que hacer el siguiente camino: [3, 5]
# 014 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 4.
# 014 - Para llegar desde 2.0 hasta 4.0 hay que hacer el siguiente camino: [2, 3, 5, 4]
# 015 - Para llegar desde 7.0 hasta 5.0 hay que hacer el siguiente camino: [7, 3, 5]
# 017 - NO SE PUEDE CONECTAR EL PUNTO 1 CON EL PUNTO 9.
# 018 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 018 - Para llegar desde 4.0 hasta 3.0 hay que hacer el siguiente camino: [4, 5, 3]
# 020 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 7.
# 020 - Para llegar desde 7.0 hasta 3.0 hay que hacer el siguiente camino: [7, 3]
# 021 - Para llegar desde 4.0 hasta 2.0 hay que hacer el siguiente camino: [4, 5, 3, 2]
# 023 - NO SE PUEDE CONECTAR EL PUNTO 5 CON EL PUNTO 0.
# 023 - Para llegar desde 7.0 hasta 8.0 hay que hacer el siguiente camino: [7, 8]
# 025 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# Los jugadores número [3] ganaron las rutas [(2, 3)]
# 000 - Para llegar desde 4.0 hasta 5.0 hay que hacer el siguiente camino: [4, 5]
# 002 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 002 - Para llegar desde 5.0 hasta 8.0 hay que hacer el siguiente camino: [5, 9, 8]
# 004 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 005 - NO SE PUEDE CONECTAR EL PUNTO 1 CON EL PUNTO 9.
# 006 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 007 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 008 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 009 - NO SE PUEDE CONECTAR EL PUNTO 7 CON EL PUNTO 0.
# 010 - NO SE PUEDE CONECTAR EL PUNTO 0 CON EL PUNTO 6.
# 011 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 012 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 7.
# 012 - Para llegar desde 3.0 hasta 5.0 hay que hacer el siguiente camino: [3, 5]
# 014 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 4.
# 014 - Para llegar desde 2.0 hasta 4.0 hay que hacer el siguiente camino: [2, 8, 9, 4]
# 015 - Para llegar desde 7.0 hasta 5.0 hay que hacer el siguiente camino: [7, 3, 5]
# 017 - NO SE PUEDE CONECTAR EL PUNTO 1 CON EL PUNTO 9.
# 018 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 018 - Para llegar desde 4.0 hasta 3.0 hay que hacer el siguiente camino: [4, 5, 3]
# 020 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 7.
# 020 - Para llegar desde 7.0 hasta 3.0 hay que hacer el siguiente camino: [7, 3]
# 021 - Para llegar desde 4.0 hasta 2.0 hay que hacer el siguiente camino: [4, 9, 8, 2]
# 023 - NO SE PUEDE CONECTAR EL PUNTO 5 CON EL PUNTO 0.
# 023 - Para llegar desde 7.0 hasta 8.0 hay que hacer el siguiente camino: [7, 8]
# 025 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# Los jugadores número [14] ganaron las rutas [(2, 8), (8, 9), (4, 9)]
# 000 - Para llegar desde 4.0 hasta 5.0 hay que hacer el siguiente camino: [4, 5]
# 002 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 002 - Para llegar desde 5.0 hasta 8.0 hay que hacer el siguiente camino: [5, 3, 7, 8]
# 004 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 005 - NO SE PUEDE CONECTAR EL PUNTO 1 CON EL PUNTO 9.
# 006 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 007 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 008 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 009 - NO SE PUEDE CONECTAR EL PUNTO 7 CON EL PUNTO 0.
# 010 - NO SE PUEDE CONECTAR EL PUNTO 0 CON EL PUNTO 6.
# 011 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 012 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 7.
# 012 - Para llegar desde 3.0 hasta 5.0 hay que hacer el siguiente camino: [3, 5]
# 014 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 4.
# 015 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 015 - Para llegar desde 7.0 hasta 5.0 hay que hacer el siguiente camino: [7, 3, 5]
# 017 - NO SE PUEDE CONECTAR EL PUNTO 1 CON EL PUNTO 9.
# 018 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 018 - Para llegar desde 4.0 hasta 3.0 hay que hacer el siguiente camino: [4, 5, 3]
# 020 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 7.
# 020 - Para llegar desde 7.0 hasta 3.0 hay que hacer el siguiente camino: [7, 3]
# 021 - Para llegar desde 4.0 hasta 2.0 hay que hacer el siguiente camino: [4, 5, 3, 7, 2]
# 023 - NO SE PUEDE CONECTAR EL PUNTO 5 CON EL PUNTO 0.
# 023 - Para llegar desde 7.0 hasta 8.0 hay que hacer el siguiente camino: [7, 8]
# 025 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# Los jugadores número [21] ganaron las rutas [(4, 5), (3, 5), (3, 7), (2, 7)]
# 001 - NO SE PUEDE CONECTAR EL PUNTO 4 CON EL PUNTO 5.
# 002 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 003 - NO SE PUEDE CONECTAR EL PUNTO 5 CON EL PUNTO 8.
# 004 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 005 - NO SE PUEDE CONECTAR EL PUNTO 1 CON EL PUNTO 9.
# 006 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 007 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 008 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 009 - NO SE PUEDE CONECTAR EL PUNTO 7 CON EL PUNTO 0.
# 010 - NO SE PUEDE CONECTAR EL PUNTO 0 CON EL PUNTO 6.
# 011 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 012 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 7.
# 012 - Para llegar desde 3.0 hasta 5.0 hay que hacer el siguiente camino: [3, 9, 5]
# 014 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 4.
# 015 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 016 - NO SE PUEDE CONECTAR EL PUNTO 7 CON EL PUNTO 5.
# 017 - NO SE PUEDE CONECTAR EL PUNTO 1 CON EL PUNTO 9.
# 018 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 019 - NO SE PUEDE CONECTAR EL PUNTO 4 CON EL PUNTO 3.
# 020 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 7.
# 021 - NO SE PUEDE CONECTAR EL PUNTO 7 CON EL PUNTO 3.
# 022 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 023 - NO SE PUEDE CONECTAR EL PUNTO 5 CON EL PUNTO 0.
# 023 - Para llegar desde 7.0 hasta 8.0 hay que hacer el siguiente camino: [7, 8]
# 025 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# Los jugadores número [12] ganaron las rutas [(3, 9), (5, 9)]
# 001 - NO SE PUEDE CONECTAR EL PUNTO 4 CON EL PUNTO 5.
# 002 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 003 - NO SE PUEDE CONECTAR EL PUNTO 5 CON EL PUNTO 8.
# 004 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 005 - NO SE PUEDE CONECTAR EL PUNTO 1 CON EL PUNTO 9.
# 006 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 007 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 008 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 009 - NO SE PUEDE CONECTAR EL PUNTO 7 CON EL PUNTO 0.
# 010 - NO SE PUEDE CONECTAR EL PUNTO 0 CON EL PUNTO 6.
# 011 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 012 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 7.
# 013 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 014 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 4.
# 015 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 016 - NO SE PUEDE CONECTAR EL PUNTO 7 CON EL PUNTO 5.
# 017 - NO SE PUEDE CONECTAR EL PUNTO 1 CON EL PUNTO 9.
# 018 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 019 - NO SE PUEDE CONECTAR EL PUNTO 4 CON EL PUNTO 3.
# 020 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 7.
# 021 - NO SE PUEDE CONECTAR EL PUNTO 7 CON EL PUNTO 3.
# 022 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 023 - NO SE PUEDE CONECTAR EL PUNTO 5 CON EL PUNTO 0.
# 023 - Para llegar desde 7.0 hasta 8.0 hay que hacer el siguiente camino: [7, 8]
# 025 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# Los jugadores número [23] ganaron las rutas [(7, 8)]
# 001 - NO SE PUEDE CONECTAR EL PUNTO 4 CON EL PUNTO 5.
# 002 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 003 - NO SE PUEDE CONECTAR EL PUNTO 5 CON EL PUNTO 8.
# 004 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 005 - NO SE PUEDE CONECTAR EL PUNTO 1 CON EL PUNTO 9.
# 006 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 007 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 008 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 009 - NO SE PUEDE CONECTAR EL PUNTO 7 CON EL PUNTO 0.
# 010 - NO SE PUEDE CONECTAR EL PUNTO 0 CON EL PUNTO 6.
# 011 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 012 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 7.
# 013 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 014 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 4.
# 015 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 016 - NO SE PUEDE CONECTAR EL PUNTO 7 CON EL PUNTO 5.
# 017 - NO SE PUEDE CONECTAR EL PUNTO 1 CON EL PUNTO 9.
# 018 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 019 - NO SE PUEDE CONECTAR EL PUNTO 4 CON EL PUNTO 3.
# 020 - NO SE PUEDE CONECTAR EL PUNTO 6 CON EL PUNTO 7.
# 021 - NO SE PUEDE CONECTAR EL PUNTO 7 CON EL PUNTO 3.
# 022 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 023 - NO SE PUEDE CONECTAR EL PUNTO 5 CON EL PUNTO 0.
# 024 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
# 025 - NO SE PUEDE CONECTAR EL PUNTO -1 CON EL PUNTO -2.
