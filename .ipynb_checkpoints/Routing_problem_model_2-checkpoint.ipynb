# %%
import sys
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import copy

# %%
n1 = 10 # cantidad de ciudades
n2 = 10  # cantidad de viajes
n3 = 10  # distancia máxima
a = 0
distance = np.zeros([n1,n1])
moves = np.zeros([n2, 2])

# %%
while (np.linalg.matrix_rank(a)!=n1):
    a = np.random.randint(n3, size=(n1,n1))
    np.fill_diagonal(a,0)
    a = np.tril(a) + np.tril(a, -1).T
print("Matriz de rutas: \n{}".format(a))
# Out:
# Matriz de rutas:
# [[0 3 7 5 2 9 2 0 7 9]
#  [3 0 6 8 4 8 4 8 9 9]
#  [7 6 0 4 2 8 2 0 4 3]
#  [5 8 4 0 5 5 3 6 1 1]
#  [2 4 2 5 0 9 8 7 8 9]
#  [9 8 8 5 9 0 5 2 3 3]
#  [2 4 2 3 8 5 0 8 5 3]
#  [0 8 0 6 7 2 8 0 0 0]
#  [7 9 4 1 8 3 5 0 0 1]
#  [9 9 3 1 9 3 3 0 1 0]]

# %%
net1 = nx.from_numpy_matrix(copy.deepcopy(a))
net2 = nx.from_numpy_matrix(copy.deepcopy(a))
for e in net1.edges():
    net2[e[0]][e[1]]['color'] = 'black'

edge_weights_list = [net2[e[0]][e[1]]['weight'] for e in net2.edges()]
nx.draw_circular(net2, with_labels=True, width=edge_weights_list)
plt.show()

# %%
rng = np.random.default_rng()
for i in range(n2):
    moves[i,:] = rng.choice(n1, size=2, replace=False)
print("Matriz de movimientos: \n{}".format(moves))
# Out:
# Matriz de movimientos:
# [[2. 9.]
#  [1. 7.]
#  [5. 8.]
#  [5. 0.]
#  [7. 9.]
#  [1. 6.]
#  [1. 5.]
#  [4. 8.]
#  [8. 6.]
#  [2. 6.]]

# %%
colores = []
for i in range(n2):
    color = np.base_repr(np.random.choice(16777215), base=16)
    colores.append('#{:0>6}'.format(color))

# %%
caminos_total = []
k_si = 0
k_no = 0
for j in range(n2):
    try:
        p = nx.dijkstra_path(net1,int(moves[j,0]),int(moves[j,1]))
        print("{:0>3} - Para llegar desde {} hasta {} hay que hacer el siguiente camino: {}".format(j+1, moves[j,0],moves[j,1], p))
        caminos_total.append(np.array(p))
        k_si += 1
        for i in range(len(p)-1):
            net2[p[i]][p[i+1]]['color'] = colores[j]
            net2[p[i]][p[i+1]]['weight'] = a[p[i], p[i+1]]
            print("      La distancia entre {} y {} es: {}".format(p[i], p[i+1], net2[p[i]][p[i+1]]['weight']))
            net1.remove_edge(p[i],p[i+1])        
    except:
        print("{:0>3} - NO SE PUEDE CONECTAR EL PUNTO {} CON EL PUNTO {}.".format(j+1, int(moves[j,0]),int(moves[j,1])))  
        k_no += 1
# Out:
# 001 - Para llegar desde 2.0 hasta 9.0 hay que hacer el siguiente camino: [2, 9]
#       La distancia entre 2 y 9 es: 3
# 002 - Para llegar desde 1.0 hasta 7.0 hay que hacer el siguiente camino: [1, 7]
#       La distancia entre 1 y 7 es: 8
# 003 - Para llegar desde 5.0 hasta 8.0 hay que hacer el siguiente camino: [5, 8]
#       La distancia entre 5 y 8 es: 3
# 004 - Para llegar desde 5.0 hasta 0.0 hay que hacer el siguiente camino: [5, 6, 0]
#       La distancia entre 5 y 6 es: 5
#       La distancia entre 6 y 0 es: 2
# 005 - Para llegar desde 7.0 hasta 9.0 hay que hacer el siguiente camino: [7, 5, 9]
#       La distancia entre 7 y 5 es: 2
#       La distancia entre 5 y 9 es: 3
# 006 - Para llegar desde 1.0 hasta 6.0 hay que hacer el siguiente camino: [1, 6]
#       La distancia entre 1 y 6 es: 4
# 007 - Para llegar desde 1.0 hasta 5.0 hay que hacer el siguiente camino: [1, 5]
#       La distancia entre 1 y 5 es: 8
# 008 - Para llegar desde 4.0 hasta 8.0 hay que hacer el siguiente camino: [4, 2, 8]
#       La distancia entre 4 y 2 es: 2
#       La distancia entre 2 y 8 es: 4
# 009 - Para llegar desde 8.0 hasta 6.0 hay que hacer el siguiente camino: [8, 3, 6]
#       La distancia entre 8 y 3 es: 1
#       La distancia entre 3 y 6 es: 3
# 010 - Para llegar desde 2.0 hasta 6.0 hay que hacer el siguiente camino: [2, 6]
#       La distancia entre 2 y 6 es: 2

# %%
edge_color_list = [net2[e[0]][e[1]]['color'] for e in net2.edges()]
edge_weights_list = [net2[e[0]][e[1]]['weight'] for e in net2.edges()]
nx.draw_circular(net2,node_color='red',edge_color = edge_color_list, with_labels = True, width=edge_weights_list)
plt.show()

# %%
caminos_total = np.array(caminos_total)
distancia_total = 0
for i in range(caminos_total.shape[0]):
    for j in range(caminos_total[i].shape[0]-1):
        if (caminos_total[i][j] != caminos_total[i][j+1]):
            distancia_total += net2[caminos_total[i][j]] [caminos_total[i][j+1]]['weight']
f_cost = (distancia_total) + (n3 * 2 * k_no)   

print("La distancia total recorrida es:", distancia_total)
print("Cantidad de autos que sí llegaron a destino:",k_si)
print("Cantidad de autos que no llegaron a destino:",k_no)
print("Distancia promedio de caminos que llegaron a destino:", (distancia_total/k_si))
print("\nFunción de coste =", f_cost)
# Out:
# La distancia total recorrida es: 50
# Cantidad de autos que sí llegaron a destino: 10
# Cantidad de autos que no llegaron a destino: 0
# Distancia promedio de caminos que llegaron a destino: 5.0
#
# Función de coste = 50
